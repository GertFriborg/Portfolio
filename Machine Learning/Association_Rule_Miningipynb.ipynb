# %% [markdown]
# # Installing and importing the necessary libraries
# We will use the apriori function from the apyori library in finding the association rules, as well as pandas and numpy for any data frame manipulation we need.
#
# https://zaxrosenberg.com/unofficial-apyori-documentation/

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5955 sha256=ef7ff4a35c796142a4213188b04b8246a0026213d00c9ad4167e1987df50592d
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
from apyori import apriori as apriori
import pandas as pd
import numpy as np

# %% [markdown]
# #1 Grocery Dataset

# %% [markdown]
# ##Prepping the dataset
# Because we are required to have 2 datasets (one grouped by member, another grouped by month) we will start first with grouping by month and then by member afterwards

# %% [markdown]
# ### By Month

# %%
df = pd.read_csv('https://raw.githubusercontent.com/efvaldez1/data-repository/main/groceries.csv')
df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %% [markdown]
# Start on preparing the data to group by month. We make a copy of the orignal dataset and then drop the Member_number column, as we are not interested in that for this grouping.

# %%
# Group By month
df1 = df.copy()
df1 = df.drop("Member_number", axis=1)

# %% [markdown]
# We drop the duplicates as this may affect the findings of the association rules

# %%
df1 = df1.drop_duplicates(keep='first')
df1
# Out:
#              Date        itemDescription
# 0      21-07-2015         tropical fruit
# 1      05-01-2015             whole milk
# 2      19-09-2015              pip fruit
# 3      12-12-2015       other vegetables
# 4      01-02-2015             whole milk
# ...           ...                    ...
# 38760  08-10-2014          sliced cheese
# 38761  23-02-2014                  candy
# 38762  16-04-2014               cake bar
# 38763  03-12-2014  fruit/vegetable juice
# 38764  26-12-2014               cat food
#
# [25231 rows x 2 columns]

# %% [markdown]
# Convert the format of values in the date column to date time objects, and then extracting only the months of each day. This will make it so that we're able to group by month regardless of year.

# %%
#convert date column to datetime
df1['Date'] = pd.to_datetime(df1['Date'])

df1['Date'] = df1['Date'].dt.month

df1
# Out:
# <ipython-input-6-163e99c6f6c1>:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df1['Date'] = pd.to_datetime(df1['Date'])
#        Date        itemDescription
# 0         7         tropical fruit
# 1         1             whole milk
# 2         9              pip fruit
# 3        12       other vegetables
# 4         2             whole milk
# ...     ...                    ...
# 38760    10          sliced cheese
# 38761     2                  candy
# 38762     4               cake bar
# 38763    12  fruit/vegetable juice
# 38764    12               cat food
#
# [25231 rows x 2 columns]

# %%
month_grouped = df1.groupby('Date')['itemDescription'].apply(list).reset_index()

# %%
month_grouped_list = month_grouped["itemDescription"].to_list()
#month_grouped_list[0]

# %% [markdown]
# ### By Member

# %% [markdown]
# Grouping by member. We drop the date column as we are not interested in that, and afterwards drop the duplicate rows.

# %%
# Group By Member
df2 = df.drop("Date", axis=1)
df2 = df2.drop_duplicates(keep='first')
df2
# Out:
#        Member_number        itemDescription
# 0               1808         tropical fruit
# 1               2552             whole milk
# 2               2300              pip fruit
# 3               1187       other vegetables
# 4               3037             whole milk
# ...              ...                    ...
# 38760           4471          sliced cheese
# 38761           2022                  candy
# 38762           1097               cake bar
# 38763           1510  fruit/vegetable juice
# 38764           1521               cat food
#
# [34766 rows x 2 columns]

# %%
member_grouped = df2.groupby('Member_number')['itemDescription'].apply(list).reset_index()

# %%
member_grouped_list = member_grouped["itemDescription"].to_list()
#member_grouped_list

# %% [markdown]
# ## Creating the rules
# Now that we have our dataframes month_grouped_list and member_grouped_list which are the dataset grouped by month and by member respectively, we can now find the rules for each grouping.
#
# We start by finding the rules for the dataset grouped by month, month_grouped_list

# %%
rules_month= apriori(month_grouped_list, min_support=1, min_confidence = 1, min_lift = 1 , min_length = 2,  max_length = 2)
results_month = list(rules_month)
results_month
# Out:
# [RelationRecord(items=frozenset({'Instant food products'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Instant food products'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({
 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'liquor (appetizer)'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'liquor (appetizer)'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'bottled beer', 'liver loaf'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bottled beer', 'liver loaf'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'liver loaf'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'liver loaf'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'bottled beer', 'long life bakery product'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bottled beer', 'long life bakery product'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'long life bakery product'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'long life bakery product'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'margarine', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'margarine', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'margarine'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'margarine'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'mayonnaise', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mayonnaise', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'mayonnaise'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'mayonnaise'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'bottled beer', 'meat'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bottled beer', 'meat'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'meat'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'meat'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'bottled beer', 'misc. beverages'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bottled beer', 'misc. beverages'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'misc. beverages'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'misc. beverages'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'mustard', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mustard', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'mustard'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'mustard'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'napkins', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'napkins', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'napkins'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'napkins'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'newspapers', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'newspapers', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'newspapers'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'newspapers'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'oil', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bottled beer', 'oil'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'oil'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'oil'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'onions', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bottled beer', 'onions'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'onions'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'onions'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'other vegetables', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'other vegetables', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'other vegetables'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'other vegetables'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'packaged fruit/vegetables', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'packaged fruit/vegetables', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'packaged fruit/vegetables'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'packaged fruit/vegetables'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'pasta', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'pasta', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'pasta'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'pastry', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bottled beer', 'pastry'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'pastry'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'pastry'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'pet care', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'pet care', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'pet care'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'pet care'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'photo/film', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'photo/film', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'photo/film'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'photo/film'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'pickled vegetables', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'pickled vegetables', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'pickled vegetables'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'pickled vegetables'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'pip fruit', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'pip fruit', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'pip fruit'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'pip fruit'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'popcorn', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'popcorn', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'popcorn'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'popcorn'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'pork', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'pork', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'pork'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'pork'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'bottled beer', 'pot plants'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bottled beer', 'pot plants'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'pot plants'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'pot plants'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'processed cheese', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'processed cheese', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'processed cheese'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'processed cheese'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'bottled beer', 'red/blush wine'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bottled beer', 'red/blush wine'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'red/blush wine'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'red/blush wine'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'roll products ', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'roll products ', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'roll products '}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'roll products '}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'bottled beer', 'rolls/buns'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bottled beer', 'rolls/buns'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'rolls/buns'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'rolls/buns'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'root vegetables', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'root vegetables', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'root vegetables'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'root vegetables'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'salt', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'salt', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'salt'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'salt'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'bottled beer', 'salty snack'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'bottled beer', 'salty snack'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'salty snack'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'salty snack'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'sauces', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'sauces', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'sauces'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'sauces'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'sausage', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'sausage', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'sausage'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'sausage'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  RelationRecord(items=frozenset({'seasonal products', 'bottled beer'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'seasonal products', 'bottled beer'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({'seasonal products'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'seasonal products'}), items_add=frozenset({'bottled beer'}), confidence=1.0, lift=1.0)]),
#  ...]

# %%
#len(results_month)
# Out:
# 7021

# %% [markdown]
# Function to make a dataframe to be able to easily see the rules and the repective confidence, support, and lift values

# %%
def create_dataframe(results):
    data = []

    for item in results:
        item_pair = item[0]
        items = [i for i in item_pair]

        if len(items) > 1:  # Check if there are two or more items
            data.append({
                'Item 1': items[0],
                'Item 2': items[1],
                'Support': item[1],
                'Confidence': str(item[2][0][2]),
                'Lift': str(item[2][0][3])
            })


    df = pd.DataFrame(data)
    return df

# %%
DF_monthresults = create_dataframe(results_month)

# %%
DF_monthresults
# Out:
#                      Item 1            Item 2  Support Confidence Lift
# 0     Instant food products          UHT-milk      1.0        1.0  1.0
# 1     Instant food products  artif. sweetener      1.0        1.0  1.0
# 2     Instant food products     baking powder      1.0        1.0  1.0
# 3     Instant food products              beef      1.0        1.0  1.0
# 4     Instant food products           berries      1.0        1.0  1.0
# ...                     ...               ...      ...        ...  ...
# 6898                 yogurt        white wine      1.0        1.0  1.0
# 6899             white wine          zwieback      1.0        1.0  1.0
# 6900                 yogurt        whole milk      1.0        1.0  1.0
# 6901               zwieback        whole milk      1.0        1.0  1.0
# 6902                 yogurt          zwieback      1.0        1.0  1.0
#
# [6903 rows x 5 columns]

# %%
DF_monthresults.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6903 entries, 0 to 6902
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Item 1      6903 non-null   object
#  1   Item 2      6903 non-null   object
#  2   Support     6903 non-null   float64
#  3   Confidence  6903 non-null   object
#  4   Lift        6903 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 269.8+ KB

# %%
DF_monthresults[["Confidence","Lift"]] = DF_monthresults[["Confidence","Lift"]].astype(float)

# %%
DF_monthresults.describe()
# Out:
#        Support  Confidence    Lift
# count   6903.0      6903.0  6903.0
# mean       1.0         1.0     1.0
# std        0.0         0.0     0.0
# min        1.0         1.0     1.0
# 25%        1.0         1.0     1.0
# 50%        1.0         1.0     1.0
# 75%        1.0         1.0     1.0
# max        1.0         1.0     1.0

# %% [markdown]
# We now proceed to finding the rules for the grouped by member

# %%
rules_member= apriori(member_grouped_list, min_support=0.001, min_confidence = 0.6, min_lift = 0 , min_length = 2, max_length = 2)
results_member = list(rules_member)
results_member
# Out:
# [RelationRecord(items=frozenset({'artif. sweetener', 'whole milk'}), support=0.004617752693689072, ordered_statistics=[OrderedStatistic(items_base=frozenset({'artif. sweetener'}), items_add=frozenset({'whole milk'}), confidence=0.6206896551724138, lift=1.354674286596903)]),
#  RelationRecord(items=frozenset({'bathroom cleaner', 'whole milk'}), support=0.0030785017957927143, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bathroom cleaner'}), items_add=frozenset({'whole milk'}), confidence=0.7058823529411765, lift=1.5406099729925566)]),
#  RelationRecord(items=frozenset({'bottled water', 'whisky'}), support=0.0012827090815802976, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whisky'}), items_add=frozenset({'bottled water'}), confidence=0.625, lift=2.9246698679471788)]),
#  RelationRecord(items=frozenset({'brandy', 'whole milk'}), support=0.0061570035915854285, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brandy'}), items_add=frozenset({'whole milk'}), confidence=0.6315789473684211, lift=1.378440502151235)]),
#  RelationRecord(items=frozenset({'canned fruit', 'other vegetables'}), support=0.0035915854284248334, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fruit'}), items_add=frozenset({'other vegetables'}), confidence=0.6666666666666666, lift=1.7702089009990916)]),
#  RelationRecord(items=frozenset({'canned fruit', 'whole milk'}), support=0.0033350436121087736, ordered_statistics=[OrderedStatistic(items_base=frozenset({'canned fruit'}), items_add=frozenset({'whole milk'}), confidence=0.619047619047619, lift=1.3510904921879163)]),
#  RelationRecord(items=frozenset({'cooking chocolate', 'other vegetables'}), support=0.002308876346844536, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking chocolate'}), items_add=frozenset({'other vegetables'}), confidence=0.6000000000000001, lift=1.5931880108991827)]),
#  RelationRecord(items=frozenset({'whole milk', 'cookware'}), support=0.0033350436121087736, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cookware'}), items_add=frozenset({'whole milk'}), confidence=0.7647058823529411, lift=1.6689941374086028)]),
#  RelationRecord(items=frozenset({'whole milk', 'curd cheese'}), support=0.008722421754746024, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd cheese'}), items_add=frozenset({'whole milk'}), confidence=0.7391304347826088, lift=1.6131749354885827)]),
#  RelationRecord(items=frozenset({'dental care', 'whole milk'}), support=0.00513083632632119, ordered_statistics=[OrderedStatistic(items_base=frozenset({'dental care'}), items_add=frozenset({'whole milk'}), confidence=0.606060606060606, lift=1.3227459364077503)]),
#  RelationRecord(items=frozenset({'other vegetables', 'frozen chicken'}), support=0.001026167265264238, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen chicken'}), items_add=frozenset({'other vegetables'}), confidence=0.7999999999999999, lift=2.1242506811989097)]),
#  RelationRecord(items=frozenset({'house keeping products', 'whole milk'}), support=0.007696254489481785, ordered_statistics=[OrderedStatistic(items_base=frozenset({'house keeping products'}), items_add=frozenset({'whole milk'}), confidence=0.6666666666666666, lift=1.4550205300485255)]),
#  RelationRecord(items=frozenset({'light bulbs', 'whole milk'}), support=0.004361210877373012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light bulbs'}), items_add=frozenset({'whole milk'}), confidence=0.6071428571428571, lift=1.3251079827227643)]),
#  RelationRecord(items=frozenset({'liquor', 'whole milk'}), support=0.016675218060543867, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liquor'}), items_add=frozenset({'whole milk'}), confidence=0.6310679611650485, lift=1.3773252590265168)]),
#  RelationRecord(items=frozenset({'whole milk', 'meat spreads'}), support=0.007183170856849667, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat spreads'}), items_add=frozenset({'whole milk'}), confidence=0.8, lift=1.7460246360582308)]),
#  RelationRecord(items=frozenset({'mustard', 'whole milk'}), support=0.014109799897383273, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mustard'}), items_add=frozenset({'whole milk'}), confidence=0.6043956043956044, lift=1.3191120190000367)]),
#  RelationRecord(items=frozenset({'nut snack', 'whole milk'}), support=0.0035915854284248334, ordered_statistics=[OrderedStatistic(items_base=frozenset({'nut snack'}), items_add=frozenset({'whole milk'}), confidence=0.6363636363636365, lift=1.3888832332281382)]),
#  RelationRecord(items=frozenset({'organic products', 'other vegetables'}), support=0.0017957927142124167, ordered_statistics=[OrderedStatistic(items_base=frozenset({'organic products'}), items_add=frozenset({'other vegetables'}), confidence=0.7000000000000001, lift=1.8587193460490465)]),
#  RelationRecord(items=frozenset({'other vegetables', 'salad dressing'}), support=0.001026167265264238, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing'}), items_add=frozenset({'other vegetables'}), confidence=0.6666666666666666, lift=1.7702089009990916)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whisky'}), support=0.0012827090815802976, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whisky'}), items_add=frozenset({'other vegetables'}), confidence=0.625, lift=1.6595708446866484)]),
#  RelationRecord(items=frozenset({'pudding powder', 'whole milk'}), support=0.0028219599794766545, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pudding powder'}), items_add=frozenset({'whole milk'}), confidence=0.6875, lift=1.500489921612542)]),
#  RelationRecord(items=frozenset({'ready soups', 'whole milk'}), support=0.0028219599794766545, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ready soups'}), items_add=frozenset({'whole milk'}), confidence=0.7333333333333333, lift=1.600522583053378)]),
#  RelationRecord(items=frozenset({'root vegetables', 'whisky'}), support=0.0015392508978963571, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whisky'}), items_add=frozenset({'root vegetables'}), confidence=0.75, lift=3.25194660734149)]),
#  RelationRecord(items=frozenset({'whole milk', 'salad dressing'}), support=0.001026167265264238, ordered_statistics=[OrderedStatistic(items_base=frozenset({'salad dressing'}), items_add=frozenset({'whole milk'}), confidence=0.6666666666666666, lift=1.4550205300485255)]),
#  RelationRecord(items=frozenset({'whole milk', 'skin care'}), support=0.0033350436121087736, ordered_statistics=[OrderedStatistic(items_base=frozenset({'skin care'}), items_add=frozenset({'whole milk'}), confidence=0.65, lift=1.4186450167973124)]),
#  RelationRecord(items=frozenset({'whole milk', 'snack products'}), support=0.004361210877373012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'snack products'}), items_add=frozenset({'whole milk'}), confidence=0.6296296296296297, lift=1.3741860561569408)]),
#  RelationRecord(items=frozenset({'whisky', 'whole milk'}), support=0.002052334530528476, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whisky'}), items_add=frozenset({'whole milk'}), confidence=1.0, lift=2.1825307950727884)]),
#  RelationRecord(items=frozenset({'zwieback', 'whole milk'}), support=0.009235505387378143, ordered_statistics=[OrderedStatistic(items_base=frozenset({'zwieback'}), items_add=frozenset({'whole milk'}), confidence=0.6000000000000001, lift=1.3095184770436732)])]

# %%
DF_memberresults = create_dataframe(results_member)

# %%
DF_memberresults.sort_values(by=['Support',"Confidence"], ascending=False)
# Out:
#                     Item 1            Item 2   Support          Confidence  \
# 13                  liquor        whole milk  0.016675  0.6310679611650485
# 15                 mustard        whole milk  0.014110  0.6043956043956044
# 27                zwieback        whole milk  0.009236  0.6000000000000001
# 8               whole milk       curd cheese  0.008722  0.7391304347826088
# 11  house keeping products        whole milk  0.007696  0.6666666666666666
# 14              whole milk      meat spreads  0.007183                 0.8
# 3                   brandy        whole milk  0.006157  0.6315789473684211
# 9              dental care        whole milk  0.005131   0.606060606060606
# 0         artif. sweetener        whole milk  0.004618  0.6206896551724138
# 25              whole milk    snack products  0.004361  0.6296296296296297
# 12             light bulbs        whole milk  0.004361  0.6071428571428571
# 4             canned fruit  other vegetables  0.003592  0.6666666666666666
# 16               nut snack        whole milk  0.003592  0.6363636363636365
# 7               whole milk          cookware  0.003335  0.7647058823529411
# 24              whole milk         skin care  0.003335                0.65
# 5             canned fruit        whole milk  0.003335   0.619047619047619
# 1         bathroom cleaner        whole milk  0.003079  0.7058823529411765
# 21             ready soups        whole milk  0.002822  0.7333333333333333
# 20          pudding powder        whole milk  0.002822              0.6875
# 6        cooking chocolate  other vegetables  0.002309  0.6000000000000001
# 26                  whisky        whole milk  0.002052                 1.0
# 17        organic products  other vegetables  0.001796  0.7000000000000001
# 22         root vegetables            whisky  0.001539                0.75
# 2            bottled water            whisky  0.001283               0.625
# 19        other vegetables            whisky  0.001283               0.625
# 10        other vegetables    frozen chicken  0.001026  0.7999999999999999
# 18        other vegetables    salad dressing  0.001026  0.6666666666666666
# 23              whole milk    salad dressing  0.001026  0.6666666666666666
#
#                   Lift
# 13  1.3773252590265168
# 15  1.3191120190000367
# 27  1.3095184770436732
# 8   1.6131749354885827
# 11  1.4550205300485255
# 14  1.7460246360582308
# 3    1.378440502151235
# 9   1.3227459364077503
# 0    1.354674286596903
# 25  1.3741860561569408
# 12  1.3251079827227643
# 4   1.7702089009990916
# 16  1.3888832332281382
# 7   1.6689941374086028
# 24  1.4186450167973124
# 5   1.3510904921879163
# 1   1.5406099729925566
# 21   1.600522583053378
# 20   1.500489921612542
# 6   1.5931880108991827
# 26  2.1825307950727884
# 17  1.8587193460490465
# 22    3.25194660734149
# 2   2.9246698679471788
# 19  1.6595708446866484
# 10  2.1242506811989097
# 18  1.7702089009990916
# 23  1.4550205300485255

# %% [markdown]
# #2 Own Dataset
# We will use ecommerce data taken from https://www.kaggle.com/datasets/carrie1/ecommerce-data. I downloaded this data and uploaded it into my google drive.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Data Cleaning

# %%
ecommerce_data = pd.read_csv('/content/gdrive/MyDrive/datasets/ecommerceData.csv',  encoding='unicode_escape')
ecommerce_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# Find out if there are null values using .info()

# %%
ecommerce_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
ecommerce_data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# Dropping these null values

# %%
ecommerce_data.dropna(inplace=True)

# %% [markdown]
# We only want to pay attention to the description and customer id, so we drop the rest of the columns

# %%
ecommerce_data_new = ecommerce_data[["Description","CustomerID"]]

# %%
df = ecommerce_data_new.groupby('CustomerID')['Description'].apply(list).reset_index()

# %% [markdown]
# Turning the item list of lists per customer to be able to be used as a parameter for the apriori function

# %%
ecommerce_item_list = df['Description'].tolist()

# %% [markdown]
# ## Creating Rules

# %%
rules_ecommerce= apriori(ecommerce_item_list, min_support=0.05, min_confidence = 0.8, min_lift = 0 , min_length = 2, max_length = 2)
results_ecommerce = list(rules_ecommerce)
results_ecommerce
# Out:
# [RelationRecord(items=frozenset({'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED '}), support=0.06061299176578225, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ALARM CLOCK BAKELIKE GREEN'}), items_add=frozenset({'ALARM CLOCK BAKELIKE RED '}), confidence=0.8204334365325077, lift=9.173746763478576)]),
#  RelationRecord(items=frozenset({'BAKING SET SPACEBOY DESIGN', 'BAKING SET 9 PIECE RETROSPOT '}), support=0.055809698078682524, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BAKING SET SPACEBOY DESIGN'}), items_add=frozenset({'BAKING SET 9 PIECE RETROSPOT '}), confidence=0.8133333333333332, lift=6.078450142450142)]),
#  RelationRecord(items=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER'}), support=0.06816102470265324, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.9283489096573208, lift=10.407029315440528)]),
#  RelationRecord(items=frozenset({'ROSES REGENCY TEACUP AND SAUCER ', 'GREEN REGENCY TEACUP AND SAUCER'}), support=0.07410795974382434, ordered_statistics=[OrderedStatistic(items_base=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'ROSES REGENCY TEACUP AND SAUCER '}), confidence=0.8307692307692307, lift=8.506143037290578)]),
#  RelationRecord(items=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), support=0.05969807868252516, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'REGENCY CAKESTAND 3 TIER'}), confidence=0.8130841121495327, lift=4.007670505431518)]),
#  RelationRecord(items=frozenset({'ROSES REGENCY TEACUP AND SAUCER ', 'PINK REGENCY TEACUP AND SAUCER'}), support=0.06244281793229643, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'ROSES REGENCY TEACUP AND SAUCER '}), confidence=0.8504672897196262, lift=8.70782901792554)]),
#  RelationRecord(items=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER', 'RED HANGING HEART T-LIGHT HOLDER'}), support=0.07136322049405307, ordered_statistics=[OrderedStatistic(items_base=frozenset({'RED HANGING HEART T-LIGHT HOLDER'}), items_add=frozenset({'WHITE HANGING HEART T-LIGHT HOLDER'}), confidence=0.8103896103896104, lift=4.129397874852421)]),
#  RelationRecord(items=frozenset({'SET OF TEA COFFEE SUGAR TINS PANTRY', 'SET OF 3 CAKE TINS PANTRY DESIGN '}), support=0.05077767612076853, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SET OF TEA COFFEE SUGAR TINS PANTRY'}), items_add=frozenset({'SET OF 3 CAKE TINS PANTRY DESIGN '}), confidence=0.8072727272727274, lift=5.514681818181819)])]

# %%
DF_ecommerce = create_dataframe(results_ecommerce)

# %%
DF_ecommerce.sort_values(by=['Support',"Confidence"], ascending=False)
# Out:
#                                 Item 1                             Item 2  \
# 3     ROSES REGENCY TEACUP AND SAUCER     GREEN REGENCY TEACUP AND SAUCER
# 6   WHITE HANGING HEART T-LIGHT HOLDER   RED HANGING HEART T-LIGHT HOLDER
# 2       PINK REGENCY TEACUP AND SAUCER    GREEN REGENCY TEACUP AND SAUCER
# 5     ROSES REGENCY TEACUP AND SAUCER      PINK REGENCY TEACUP AND SAUCER
# 0           ALARM CLOCK BAKELIKE GREEN          ALARM CLOCK BAKELIKE RED
# 4       PINK REGENCY TEACUP AND SAUCER           REGENCY CAKESTAND 3 TIER
# 1           BAKING SET SPACEBOY DESIGN      BAKING SET 9 PIECE RETROSPOT
# 7  SET OF TEA COFFEE SUGAR TINS PANTRY  SET OF 3 CAKE TINS PANTRY DESIGN
#
#     Support          Confidence                Lift
# 3  0.074108  0.8307692307692307   8.506143037290578
# 6  0.071363  0.8103896103896104   4.129397874852421
# 2  0.068161  0.9283489096573208  10.407029315440528
# 5  0.062443  0.8504672897196262    8.70782901792554
# 0  0.060613  0.8204334365325077   9.173746763478576
# 4  0.059698  0.8130841121495327   4.007670505431518
# 1  0.055810  0.8133333333333332   6.078450142450142
# 7  0.050778  0.8072727272727274   5.514681818181819
